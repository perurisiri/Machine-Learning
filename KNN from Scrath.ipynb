# %% [markdown]
# ### Step - 1: Load the data

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r'C:\Users\Sireesha Peruri\Downloads\diamonds (1).csv')

# %%
data.shape
# Out:
# (53940, 10)

# %%
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ### Step - 2: Identify input and output variables

# %%
X = data.drop('price', axis=1)
y = data['price']

# %%
X.shape,y.shape
# Out:
# ((53940, 9), (53940,))

# %% [markdown]
# ### Step - 3: Split the data - Test and Train

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42 )
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((40455, 9), (13485, 9), (40455,), (13485,))

# %%
data['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# ### Step - 4: Data Preprocessing on X_train

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
data['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
data['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
data['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
cut_order = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_order = ['D', 'E', 'F', 'G', 'H', 'I', 'J']
clarity_order = ['I1', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2', 'IF']
oe = OrdinalEncoder(categories = [cut_order, color_order, clarity_order])
oe
# Out:
# OrdinalEncoder(categories=[['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],
#                            ['D', 'E', 'F', 'G', 'H', 'I', 'J'],
#                            ['I1', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2',
#                             'IF']])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler().set_output(transform = 'pandas')
minmax
# Out:
# MinMaxScaler()

# %%
from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer([('oe', oe, ['cut','color','clarity']),
                        ('minmax',minmax,['depth','carat','table'])],
                       remainder = 'drop').set_output(transform = 'pandas')
ct
# Out:
# ColumnTransformer(transformers=[('oe',
#                                  OrdinalEncoder(categories=[['Fair', 'Good',
#                                                              'Very Good',
#                                                              'Premium',
#                                                              'Ideal'],
#                                                             ['D', 'E', 'F', 'G',
#                                                              'H', 'I', 'J'],
#                                                             ['I1', 'SI1', 'SI2',
#                                                              'VS1', 'VS2',
#                                                              'VVS1', 'VVS2',
#                                                              'IF']]),
#                                  ['cut', 'color', 'clarity']),
#                                 ('minmax', MinMaxScaler(),
#                                  ['depth', 'carat', 'table'])])

# %%
ct.fit_transform(data[:])
# Out:
#        oe__cut  oe__color  oe__clarity  minmax__depth  minmax__carat  \
# 0          4.0        1.0          2.0       0.513889       0.006237
# 1          3.0        1.0          1.0       0.466667       0.002079
# 2          1.0        1.0          3.0       0.386111       0.006237
# 3          3.0        5.0          4.0       0.538889       0.018711
# 4          1.0        6.0          2.0       0.563889       0.022869
# ...        ...        ...          ...            ...            ...
# 53935      4.0        0.0          1.0       0.494444       0.108108
# 53936      1.0        0.0          1.0       0.558333       0.108108
# 53937      2.0        0.0          1.0       0.550000       0.103950
# 53938      3.0        4.0          2.0       0.500000       0.137214
# 53939      4.0        0.0          2.0       0.533333       0.114345
#
#        minmax__table
# 0           0.230769
# 1           0.346154
# 2           0.423077
# 3           0.288462
# 4           0.288462
# ...              ...
# 53935       0.269231
# 53936       0.230769
# 53937       0.326923
# 53938       0.288462
# 53939       0.230769
#
# [53940 rows x 6 columns]

# %%
X_train_transformed = ct.fit_transform(X_train)
X_train_transformed.head()
# Out:
#        oe__cut  oe__color  oe__clarity  minmax__depth  minmax__carat  \
# 35965      1.0        1.0          6.0       0.608333       0.010395
# 52281      4.0        6.0          1.0       0.522222       0.133056
# 6957       3.0        6.0          4.0       0.502778       0.176715
# 9163       4.0        2.0          2.0       0.491667       0.170478
# 50598      4.0        2.0          3.0       0.522222       0.085239
#
#        minmax__table
# 35965       0.288462
# 52281       0.250000
# 6957        0.288462
# 9163        0.250000
# 50598       0.269231

# %% [markdown]
# ### Step - 5: Data Preprocessing on X_test

# %%
X_test_transformed = ct.transform(X_test)
X_test_transformed.head()
# Out:
#        oe__cut  oe__color  oe__clarity  minmax__depth  minmax__carat  \
# 1388       4.0        3.0          5.0       0.530556       0.008316
# 50052      2.0        2.0          6.0       0.472222       0.079002
# 41645      4.0        1.0          6.0       0.530556       0.041580
# 42377      3.0        1.0          6.0       0.494444       0.047817
# 17244      4.0        1.0          2.0       0.536111       0.280665
#
#        minmax__table
# 1388        0.250000
# 50052       0.269231
# 41645       0.230769
# 42377       0.269231
# 17244       0.230769

# %% [markdown]
# ### Step - 6: Build the model and predict on X_test

# %%
query=X_train_transformed.sample(1)
query
# Out:
#        oe__cut  oe__color  oe__clarity  minmax__depth  minmax__carat  \
# 18315      2.0        2.0          3.0          0.525        0.16632
#
#        minmax__table
# 18315       0.288462

# %%
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics import pairwise_distances

# %%
dist=euclidean_distances(X_train_transformed,query)
dist
# Out:
# array([[3.32133363],
#        [4.89924418],
#        [4.24271162],
#        ...,
#        [4.00267134],
#        [4.5827314 ],
#        [2.23664554]])

# %%
nearest= np.argsort(dist, axis = 0)
nearest
# Out:
# array([[ 7456],
#        [22522],
#        [ 2445],
#        ...,
#        [30460],
#        [12428],
#        [ 2491]], dtype=int64)

# %%
top5_np=nearest[:5].flatten()
top5_np
# Out:
# array([ 7456, 22522,  2445, 39812, 23164], dtype=int64)

# %%
y[top5_np].mean()
# Out:
# 6051.4

# %%
def euclidean_distance(x_test, X_train):
    return np.sqrt(np.sum((X_train - x_test) ** 2, axis=1))

y_new= []
k = 5
for i in range(X_test_transformed.shape[0]):

    distances = euclidean_distance(
        X_test_transformed.iloc[i].values,
        X_train_transformed.values
    )
    knn_indices = np.argsort(distances)[:k]
    y_pred = np.mean(y_train.iloc[knn_indices])
    y_new.append(y_pred)

# %%
y_pred2 = knn.predict(X_test_transformed)
y_pred2
# Out:
# array([ 559, 1891, 1034, ..., 6543, 4497, 4370], dtype=int64)

# %%
nearest= np.argsort(dist, axis = 0)
nearest
# Out:
# array([[ 7456],
#        [22522],
#        [ 2445],
#        ...,
#        [30460],
#        [12428],
#        [ 2491]], dtype=int64)

# %%
top5=nearest[:5].flatten()
top5
# Out:
# array([ 7456, 22522,  2445, 39812, 23164], dtype=int64)

# %%
y[top5].mean()
# Out:
# 6051.4

# %% [markdown]
#  ### Step - 7: Evaluate your model

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mean_squared_error(y_pred2,y_test)
# Out:
# 1924555.043233222

# %% [markdown]
# ### Step - 8: Train a model using sklearn KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5,metric='minkowski') 
knn

# %%
knn.fit(X_train_transformed, y_train)

# %%
y_pred_knn = knn.predict(X_test_transformed)
y_pred_knn
# Out:
# array([ 559, 1891, 1034, ..., 6543, 4497, 4370], dtype=int64)

# %%
nearest= np.argsort(dist, axis = 0)
nearest
# Out:
# array([[ 7456],
#        [22522],
#        [ 2445],
#        ...,
#        [30460],
#        [12428],
#        [ 2491]], dtype=int64)

# %%
top5=nearest[:5].flatten()
top5
# Out:
# array([ 7456, 22522,  2445, 39812, 23164], dtype=int64)

# %%
y[top5].mean()
# Out:
# 6051.4

# %%
mean_squared_error(y_pred_knn,y_test)
# Out:
# 1924555.043233222
